# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephDiPirro/JosephDiPirro.github.io/blob/main/DiPirroHW8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Define the following terms: #

# %% [markdown]
# Pwd #
#
# ls #
#
# cd #
#
# mkdir #
#
# echo "hello" #
#
# echo "Hello" > hello.txt #
#
# cat Hello.txt #
#
# mv hello.txt #
#
# histroy #
#
# sudo apt update #
#
# sudo apt upgrade #
#
# sudo apt install micro #
#
# micro hello.py #
#
# python3 hello.py #
#
# ping #
#
# gcc main.c #
#
# sudo apt install micro #
#
# sudo apt install build-essential #

# %% [markdown]
# In the cell below, enter the magic command to install ping (then execute the cell)

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# In the cell below run the magic command to ping your google cloud vm. (press stop button after a few pings)
